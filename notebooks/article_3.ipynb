# %% [markdown]
# # **Comparing different models**

# %%
import pandas as pd
import os
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from matplotlib import pyplot as plt

# %%
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /Users/gabrielaarzate/Desktop/predicting_startup_succes/notebooks

# %%
notebook_directory = 'notebooks'
file_name = 'cleaned_data.csv'
file_path = os.path.join('..', 'notebooks', 'cleaned_data.csv')
data_df = pd.read_csv(file_path, encoding="ISO-8859-1")

# %%
data_df
# Out:
#      state_code  city  closed_at  age_first_funding_year  \
# 0             0     0          0                  0.1534
# 1             0     1          0                  0.2164
# 2             1     2          0                  1.8822
# 3             1     2          0                  1.3014
# 4             0     3          0                  1.2164
# ..          ...   ...        ...                     ...
# 918           1     2          1                  0.0000
# 919           9   103          1                  5.6301
# 920           0     3          1                  0.5178
# 921           0     3          1                  0.7589
# 922           0    53          1                  3.1205
#
#      age_last_funding_year  age_first_milestone_year  age_last_milestone_year  \
# 0                   2.3425                    0.0630                   1.5836
# 1                   4.8438                    0.2164                   6.2466
# 2                   1.8822                    1.6603                   3.0247
# 3                   2.4685                    0.0000                   2.4685
# 4                   1.2164                    1.4164                   2.6822
# ..                     ...                       ...                      ...
# 918                 3.9288                    2.9151                   5.7342
# 919                 8.7589                    8.5041                   8.7589
# 920                 0.5178                    0.5808                   4.5260
# 921                 2.8329                    0.7589                   3.8356
# 922                 3.1205                    4.0027                   4.0027
#
#      relationships  funding_rounds  funding_total_usd  ...  founded_year  \
# 0                8               2            3000000  ...             0
# 1               22               5           70000000  ...             1
# 2                5               1            1000000  ...             0
# 3                3               2            1800000  ...             2
# 4                6               1            5500000  ...             3
# ..             ...             ...                ...  ...           ...
# 918             16               3           18000000  ...             8
# 919              9               5          122500000  ...             9
# 920              9               1            1100000  ...             0
# 921             12               2           15500000  ...             0
# 922              4               1           20000000  ...             6
#
#      negative_first_funding  negative_last_funding  negative_first_milestone  \
# 0                         1                      0                         0
# 1                         0                      0                         0
# 2                         0                      0                         0
# 3                         0                      0                         0
# 4                         0                      0                         0
# ..                      ...                    ...                       ...
# 918                       0                      0                         0
# 919                       0                      0                         0
# 920                       0                      0                         0
# 921                       0                      0                         0
# 922                       0                      0                         0
#
#      negative_last_milestone  is_outlier      age  founded_at_days  \
# 0                          0           0   4.2601             9339
# 1                          0           0   6.2916             8582
# 2                          0           0   4.7365             9132
# 3                          0           0   3.0198             9740
# 4                          0           0   2.6804             9862
# ..                       ...         ...      ...              ...
# 918                        0           0   7.1485             8284
# 919                        0           0  13.8289             5844
# 920                        0           0   4.8268             9132
# 921                        0           0   4.8268             9132
# 922                        0           0  10.8282             6940
#
#      first_funding_at_days  last_funding_at_days
# 0                     9283                 10194
# 1                     8661                 10350
# 2                     9819                  9819
# 3                    10215                 10641
# 4                    10306                 10306
# ..                     ...                   ...
# 918                   8284                  9718
# 919                   7899                  9041
# 920                   9321                  9321
# 921                   9409                 10166
# 922                   8079                  8079
#
# [923 rows x 31 columns]
